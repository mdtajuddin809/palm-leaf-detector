# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6MY6O1xKJB4Ot0VCdq1t")
project = rf.workspace("md-tajuddin-lgvf3").project("palm-leaf-detection")
version = project.version(2)
dataset = version.download("yolov8")

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # upgrade model 🔥

model.train(
    data="/content/Palm-Leaf-Detection-1/data.yaml",
    epochs=100,
    imgsz=640
)

# %%
# !ls /content/runs/detect/train2/weights

# %% [markdown]
# ## model download

# %%
from google.colab import files

files.download('/content/runs/detect/train3/weights/best.pt')

# %%
# !zip -r model.zip /content/runs/detect/train3/weights/
from google.colab import files
files.download('model.zip')

# %% [markdown]
# ### Prediction

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train2/weights/best.pt")

results = model.predict(r"/content/Palm-Leaf-Detection-2/test/images/nitrogen-2193-_jpg.rf.3fc2703396adb679af586411314e6480.jpg", show=True)

# %% [markdown]
# # Downloading file in local

# %%
# !zip -r Palm-Leaf-Detection-2.zip /content/Palm-Leaf-Detection-2

# %%
from google.colab import files
files.download('Palm-Leaf-Detection-2.zip')
